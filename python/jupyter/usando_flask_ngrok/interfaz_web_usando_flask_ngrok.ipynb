# %%
# !pip install flask pandas pyngrok
# Out:
# ...
#   Using cached flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# ...
#   Using cached pyngrok-7.1.6-py3-none-any.whl.metadata (7.4 kB)
# ...
#   Using cached werkzeug-3.0.3-py3-none-any.whl.metadata (3.7 kB)
# ...
#   Using cached itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# ...
# Using cached flask-3.0.3-py3-none-any.whl (101 kB)
# Using cached pyngrok-7.1.6-py3-none-any.whl (22 kB)
# Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# ...
#    ---------------------------------------- 0.0/227.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/227.3 kB ? eta -:--:--
#    - -------------------------------------- 10.2/227.3 kB ? eta -:--:--
#    - -------------------------------------- 10.2/227.3 kB ? eta -:--:--
#    - -------------------------------------- 10.2/227.3 kB ? eta -:--:--
#    ----- --------------------------------- 30.7/227.3 kB 163.8 kB/s eta 0:00:02
#    ----- --------------------------------- 30.7/227.3 kB 163.8 kB/s eta 0:00:02
# ...

# %%
from pyngrok import ngrok
# Usa tu authtoken de ngrok
authtoken = "user de ngrok" # Reemplaza esto con tu authtoken de ngrok
ngrok.set_auth_token(authtoken)
